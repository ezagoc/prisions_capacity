# %%
import pandas as pd
import numpy as np
from dbfread import DBF

pf = '../../../data/01-judicial/00-sentencing/raw/Judiciales_BD_Catalogos_2009_dbf/'

table = DBF(f'{pf}CatalogosMicrodatos_2009/CDEL2009.DBF')


df = pd.DataFrame(iter(table))
df.to_excel(f'{pf}CatalogosMicrodatos_2009/CDEL2009.xlsx', index = False)

# %%
df = df.drop_duplicates('DESC_DEL').reset_index(drop=True)
# Out:
#      CVE_DEL                                           DESC_DEL
# 0     111100                                          Homicidio
# 1     111101                                          Homicidio
# 2     111102                               Homicidio calificado
# 3     111103                                  Homicidio culposo
# 4     111104                                  Homicidio en ri¤a
# ...      ...                                                ...
# 1252  611999  Delito insuficientemente especificado contra e...
# 1253  699900  Delitos contra el Estado no considerados anter...
# 1254  699999  Delitos contra el Estado no considerados anter...
# 1255  999900                             Delito no especificado
# 1256  999999                             Delito no especificado
#
# [1257 rows x 2 columns]
