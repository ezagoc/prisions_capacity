# %%
import pandas as pd
import json
import numpy as np
import os
import re
from pathlib import Path
from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest

endpoint = "https://ocrzagoprice2.cognitiveservices.azure.com/"
key = "B9UhzXXGyeA99K4MJUTdQLtwgmdkCwA1cwrpaFzIYS79fpOSWj0MJQQJ99BEACYeBjFXJ3w3AAALACOGFMZG"

document_intelligence_client  = DocumentIntelligenceClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

def column_contains_keyword(series):
    return series.astype(str).str.lower().apply(
        lambda val: any(kw in val for kw in keywords)
    ).any()

# %%
# First try
formUrl = "https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_01_CE.pdf"

poller = document_intelligence_client.begin_analyze_document(
    "prebuilt-layout", AnalyzeDocumentRequest(url_source=formUrl)
)
result = poller.result()

df_final = pd.DataFrame()
for idx, table in enumerate(result.tables):
    rows = table['rowCount']
    cols = table['columnCount']
    grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

    for cell in table['cells']:
        r = cell['rowIndex']
        c = cell['columnIndex']
        val = cell.get('content', '').strip()
        if val:
            grid[r][c] = val

    df = pd.DataFrame(grid)
    df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
    new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
    df.rename(columns=new_column_names, inplace=True)
    for col in range(1, df.shape[1]):
        if pd.isna(df.iat[0, col]):
            df.iat[0, col] = df.iat[0, col - 1]
    
    # Define keywords to search for
    keywords = ["TOTAL", "Capacidad", "Subtotal"]

    # Normalize to lowercase for matching
    keywords = [k.lower() for k in keywords]

    # Filter: keep only rows that match any keyword
    # Identify columns to keep
    columns_to_keep = [col for col in df.columns if column_contains_keyword(df[col])]
    actual = list(set(['col1'] + columns_to_keep))
    print(actual)
    # Filter the DataFrame
    df = df[actual]

    new_columns = []

    for i, val in enumerate(df.iloc[0]):
        if isinstance(val, str) and 'Centro' in val:
            new_columns.append('center_name')
        elif isinstance(val, str) and 'Capacidad' in val:
            new_columns.append('capacity')
        elif isinstance(val, str) and 'FEDERAL' in val:
            new_columns.append('federal')
        elif isinstance(val, str) and 'COMUN' in val:
            new_columns.append('comun')
        else:
            new_columns.append(f'total')  # fallback/default name

    # Set the new column names and drop the first row
    df.columns = new_columns
    df = df[1:].reset_index(drop=True)

    df_final = pd.concat([df_final, df])

df_final = df_final[~df_final['center_name'].isnull()]
df_final['month'] = 1
df_final['year'] = 2000

df_final.to_excel('../../../data/00-map/capacity/raw/2000/capacity_1.xlsx', index = False)

# %%
# First OCR every month

year = 2000
for i in range(2, 13):
    ii = f"{i:02d}"
    formUrl = f"https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/{year}/{year}_{ii}_CE.pdf"
    print(formUrl)
    poller = document_intelligence_client.begin_analyze_document(
        "prebuilt-layout", AnalyzeDocumentRequest(url_source=formUrl))
    result = poller.result()
    for idx, table in enumerate(result.tables):
        rows = table['rowCount']
        cols = table['columnCount']
        grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

        for cell in table['cells']:
            r = cell['rowIndex']
            c = cell['columnIndex']
            val = cell.get('content', '').strip()
            if val:
                grid[r][c] = val

        df = pd.DataFrame(grid)
        df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
        new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
        df.rename(columns=new_column_names, inplace=True)

        folder = Path(f"../../../data/00-map/capacity/raw/2000/tables{ii}")
        folder.mkdir(parents=True, exist_ok=True)

        df.to_parquet(f"../../../data/00-map/capacity/raw/2000/tables{ii}/table_{idx}.parquet.gzip", 
                      index = False, compression = 'gzip')



keywords = ["TOTAL", "Capacidad", "Subtotal"]
keywords = [k.lower() for k in keywords]

for e in range(2, 13): 
    print(e)
    ii = f"{e:02d}"
    table_path = f"../../../data/00-map/capacity/raw/2000/tables{ii}"
    files = [f for f in os.listdir(table_path) if f.endswith(".gzip")]
    files_sorted = sorted(files, key=lambda x: int(re.search(r'(\d+)', x).group()))
    df_final = pd.DataFrame()

    for table in files_sorted:
        df = pd.read_parquet(f'{table_path}/{table}')
        for col in range(1, df.shape[1]):
            if pd.isna(df.iat[0, col]):
                df.iat[0, col] = df.iat[0, col - 1]
    
    

    # Filter: keep only rows that match any keyword
    # Identify columns to keep
        columns_to_keep = [col for col in df.columns if column_contains_keyword(df[col])]
        actual = list(set(['col1'] + columns_to_keep))
        print(actual)
    # Filter the DataFrame
        df = df[actual]

        new_columns = []

        for i, val in enumerate(df.iloc[0]):
            if isinstance(val, str) and 'Centro' in val:
                new_columns.append('center_name')
            elif isinstance(val, str) and 'Capacidad' in val:
                new_columns.append('capacity')
            elif isinstance(val, str) and 'FEDERAL' in val:
                new_columns.append('federal')
            elif isinstance(val, str) and 'COMUN' in val:
                new_columns.append('comun')
            else:
                new_columns.append(f'total')  # fallback/default name

    # Set the new column names and drop the first row
        df.columns = new_columns
        df = df.loc[:, ~df.columns.duplicated()]
        df = df[1:].reset_index(drop=True)

        df_final = pd.concat([df_final, df])
        df_final = df_final[~df_final['center_name'].isnull()]
        df_final['month'] = e
        df_final['year'] = 2000

        df_final.to_excel(f'../../../data/00-map/capacity/raw/2000/capacity_{e}.xlsx', index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_03_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_04_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_05_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_06_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_07_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_08_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_09_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_10_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_11_CE.pdf
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2000/2000_12_CE.pdf

# %%
# Function: Takes the year and month, OCRs it and gives you the result (and saves the parquet files for later)
from unidecode import unidecode

keywords = ["TOTAL", "Capacidad", "Subtotal", 'Espacios']
keywords = [k.lower() for k in keywords]

def ocr_parquet(month, year, to_parquet = True):
    month_string = f"{month:02d}"
    formUrl = f"https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/{year}/{year}_{month_string}_CE.pdf"
    print(formUrl)
    poller = document_intelligence_client.begin_analyze_document(
        "prebuilt-layout", AnalyzeDocumentRequest(url_source=formUrl))
    result = poller.result()

    if to_parquet:
        for idx, table in enumerate(result.tables):
            rows = table['rowCount']
            cols = table['columnCount']
            grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

            for cell in table['cells']:
                r = cell['rowIndex']
                c = cell['columnIndex']
                val = cell.get('content', '').strip()
                if val:
                    grid[r][c] = val

            df = pd.DataFrame(grid)
            df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
            new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
            df.rename(columns=new_column_names, inplace=True)

            folder = Path(f"../../../data/00-map/capacity/raw/{year}/tables{month_string}")
            folder.mkdir(parents=True, exist_ok=True)

            df.to_parquet(f"../../../data/00-map/capacity/raw/{year}/tables{month_string}/table_{idx}.parquet.gzip", 
                      index = False, compression = 'gzip')
        print(f'Parquets generated in path: {folder}')
    
    else:
        print('No parquet generated')
    return(result)


# Function that cleans the ocr output from the result object: 

def clean_ocr(result_ocr):
    df_final = pd.DataFrame()
    for idx, table in enumerate(result_ocr.tables):
        rows = table['rowCount']
        cols = table['columnCount']
        grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

        for cell in table['cells']:
            r = cell['rowIndex']
            c = cell['columnIndex']
            val = cell.get('content', '').strip()
            if val:
                grid[r][c] = val

        df = pd.DataFrame(grid)
        df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
        new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
        df.rename(columns=new_column_names, inplace=True)

    
        for col in range(1, df.shape[1]):
            if pd.isna(df.iat[0, col]):
                df.iat[0, col] = df.iat[0, col - 1]
    
    

        # Filter: keep only rows that match any keyword
        # Identify columns to keep
    
        columns_to_keep = [col for col in df.columns if column_contains_keyword(df[col])]
        actual = list(set(['col1'] + columns_to_keep))
        if len(actual) < 5:
            print('This file contains at least one missing column, check')
        # Filter the DataFrame
        df = df[actual]

        new_columns = []

        for i, val in enumerate(df.iloc[0]):
            if isinstance(val, str) and 'centro' in val.lower():
                new_columns.append('center_name')
            elif isinstance(val, str) and ('capacidad' in val.lower() or 'espacios' in val.lower()):
                new_columns.append('capacity')
            elif isinstance(val, str) and 'federal' in val.lower():
                new_columns.append('federal')
            elif isinstance(val, str) and 'comun' in unidecode(val).lower():
                new_columns.append('comun')
            else:
                new_columns.append(f'total')  # fallback/default name

    # Set the new column names and drop the first row
        df.columns = new_columns
        df = df.loc[:, ~df.columns.duplicated()]
        df = df[1:].reset_index(drop=True)

        df_final = pd.concat([df_final, df])
    return(df_final)

# %%
# First try, verify that the ocr is the thing that is wrong, not the code
result1 = ocr_parquet(month = 12, year = 2003)

df_final = clean_ocr(result1)

df_final = df_final[~df_final['center_name'].isnull()]
df_final['month'] = 12
df_final['year'] = 2003

df_final.to_excel(f'../../../data/00-map/capacity/raw/{2003}/capacity_{12}.xlsx', 
                          index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables12

# %%
# 2001 - 2002
for y in range(2001, 2003):
    for m in range(1, 13): 
        result1 = ocr_parquet(month = m, year = y)
        df_final = clean_ocr(result1)
        df_final = df_final[~df_final['center_name'].isnull()]
        df_final['month'] = m
        df_final['year'] = y

        df_final.to_excel(f'../../../data/00-map/capacity/raw/{y}/capacity_{m}.xlsx', 
                          index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_01_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables01
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_02_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables02
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_03_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables03
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_04_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables04
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_05_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables05
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_06_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables06
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_07_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables07
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_08_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables08
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_09_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables09
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_10_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables10
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_11_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables11
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2001/2001_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2001\tables12
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_01_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables01
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_02_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables02
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_03_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables03
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_04_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables04
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_05_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables05
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_06_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables06
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_07_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables07
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_08_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables08
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_09_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables09
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_10_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables10
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_11_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables11
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2002/2002_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2002\tables12
# This file contains at least one missing column, check
# This file contains at least one missing column, check

# %%
for y in range(2003, 2004):
    for m in range(1, 13): 
        result1 = ocr_parquet(month = m, year = y)
        df_final = clean_ocr(result1)
        df_final = df_final[~df_final['center_name'].isnull()]
        df_final['month'] = m
        df_final['year'] = y

        df_final.to_excel(f'../../../data/00-map/capacity/raw/{y}/capacity_{m}.xlsx', 
                          index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_01_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables01
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_02_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables02
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_03_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables03
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_04_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables04
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_05_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables05
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_06_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables06
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_07_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables07
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_08_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables08
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_09_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables09
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_10_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables10
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_11_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables11
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2003/2003_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2003\tables12
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'center_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
#       3 result1 = ocr_parquet(month = m, year = y)
#       4 df_final = clean_ocr(result1)
# ----> 5 df_final = df_final[~df_final['center_name'].isnull()]
#       6 df_final['month'] = m
#       7 df_final['year'] = y
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\Dell\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'center_name'

# %%
for y in range(2004, 2005):
    for m in range(1, 13): 
        result1 = ocr_parquet(month = m, year = y)
        df_final = clean_ocr(result1)
        df_final = df_final[~df_final['center_name'].isnull()]
        df_final['month'] = m
        df_final['year'] = y

        df_final.to_excel(f'../../../data/00-map/capacity/raw/{y}/capacity_{m}.xlsx', 
                          index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_01_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables01
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_02_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables02
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_03_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables03
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_04_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables04
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_05_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables05
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_06_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables06
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_07_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables07
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_08_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables08
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_09_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables09
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_10_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables10
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_11_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables11
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2004/2004_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2004\tables12
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check

# %%
for y in range(2005, 2006):
    for m in range(1, 13): 
        result1 = ocr_parquet(month = m, year = y)
        df_final = clean_ocr(result1)
        df_final = df_final[~df_final['center_name'].isnull()]
        df_final['month'] = m
        df_final['year'] = y

        df_final.to_excel(f'../../../data/00-map/capacity/raw/{y}/capacity_{m}.xlsx', 
                          index = False)
# Out:
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_01_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables01
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_02_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables02
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_03_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables03
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_04_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables04
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_05_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables05
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_06_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables06
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_07_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables07
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_08_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables08
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_09_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables09
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_10_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables10
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_11_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables11
# https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/2005/2005_12_CE.pdf
# Parquets generated in path: ..\..\..\data\00-map\capacity\raw\2005\tables12
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check
# This file contains at least one missing column, check

# %%
# analyze tables

df = pd.read_parquet('../../../data/00-map/capacity/raw/2003/tables12/table_1.parquet.gzip')
df
# Out:
#                                                  col1      col2  \
# 0   ENTIDAD FEDERATIVA / CENTRO PENITENCIARIO FEDERAL  ESPACIOS
# 1                                                None      None
# 2                                                None      None
# 3                             CRS Número 9 Acapetahua       200
# 4                  CRS Número 16 Ocosingo (El Encino)       120
# 5                               CRS Número 12 Yajalón       132
# 6                      CRS Número 4 Femenil Tapachula        64
# 7                                CRS Número 7 Huixtla        40
# 8   Centro Estatal Preventivo Numero 1 Chiapa de C...       146
# 9                             CRS Numero 15 Copainalá       120
# 10                                          Chihuahua     7,386
# 11                           CERESO Estatal Femenil 1       229
# 12                                  CRS Estatal No. 1     1,894
# 13                                  CRS Estatal No. 2       995
# 14                                  CRS Estatal No. 3     2,852
# 15                                  CRS Estatal No. 4       292
# 16                                  CRS Estatal No. 5       168
# 17                                  CRS Estatal No. 7       376
# 18                           CRS Estatal Femenil Nº 2       260
# 19                                   CRS Estatal Nº 8       320
# 20                                   Ciudad de México    28,969
# 21               Penitenciaria de la Ciudad de México     3,620
# 22  Centro de Ejecución de Sanciones Penales Varon...       338
# 23  Centro Varonil de Rehabilitación Psicosocial d...       444
# 24  Centro de Ejecución de Sanciones Penales Varon...       250
# 25                Reclusorio Preventivo Varonil Norte     6,519
# 26              Reclusorio Preventivo Varonil Oriente     5,931
# 27                  Reclusorio Preventivo Varonil Sur     5,063
# 28  Centro Varonil de Reinserción Social Santa Mar...     3,223
# 29  Centro Femenil de Reinserción Social Santa Mar...     1,543
# 30               Centro Femenil de Reinserción Social       415
# 31           Institución Abierta Casa de Medio Camino        87
# 32        Centro Varonil de Seguridad Penitenciaria I       768
# 33       Centro Varonil de Seguridad Penitenciaria II       768
#
#               col3      col4                 col5  col6  \
# 0   Sobrepoblación      None          FUERO COMÚN  None
# 1         Absoluta  Relativa  Personas Procesadas  None
# 2             None      None                    H     M
# 3             -200  -100.00%                 None  None
# 4              187   155.83%                  120  None
# 5                2     1.52%                   66  None
# 6               -4    -6.25%                 None    34
# 7               90      225%                   75  None
# 8              -69   -47.26%                   47  None
# 9              -42   -35.00%                   34  None
# 10           1,419    19.21%                2,355   146
# 11             -42   -18.34%                 None    50
# 12             663    35.01%                  548  None
# 13            -338   -33.97%                   59  None
# 14           1,244    43.62%                1,482  None
# 15              -7    -2.40%                   59  None
# 16             -25   -14.88%                   39  None
# 17              27     7.18%                  158  None
# 18              36    13.85%                 None    96
# 19            -139   -43.44%                   10  None
# 20          -3,512   -12.12%                5,445   525
# 21            -407   -11.24%                   54  None
# 22            -265   -78.40%                 None  None
# 23            -187   -42.12%                  103  None
# 24            -136   -54.40%                 None  None
# 25            -285    -4.37%                1,640  None
# 26           1,627    27.43%                2,589  None
# 27          -1,261   -24.91%                1,026  None
# 28          -1,845   -57.24%                   17  None
# 29            -207   -13.42%                 None   491
# 30            -253   -60.96%                 None    34
# 31             -57   -65.52%                    1  None
# 32             -71    -9.24%                    9  None
# 33            -165   -21.48%                    6  None
#
#                      col7  col8      col9    col10                col11 col12  \
# 0                    None  None      None     None        FUERO FEDERAL  None
# 1   Personas Sentenciadas  None  Subtotal        %  Personas Procesadas  None
# 2                       H     M      None     None                    H     M
# 3                    None  None         0    0.00%                 None  None
# 4                     187  None       307  100.00%                 None  None
# 5                      68  None       134  100.00%                 None  None
# 6                    None    21        55   91.67%                 None     1
# 7                      55  None       130  100.00%                 None  None
# 8                      30  None        77  100.00%                 None  None
# 9                      43  None        77   98.72%                 None  None
# 10                  4,848   203     7,552   85.77%                  476    64
# 11                   None   106       156   83.42%                 None    10
# 12                  1,601  None     2,149   84.04%                  113  None
# 13                    549  None       608   92.54%                    4  None
# 14                  1,983  None     3,465   84.59%                  357  None
# 15                    209  None       268   94.04%                 None  None
# 16                    103  None       142   99.30%                 None  None
# 17                    233  None       391   97.02%                    2  None
# 18                   None    97       193   65.20%                 None    54
# 19                    170  None       180   99.45%                 None  None
# 20                 16,086   803    22,859   89.79%                  405    66
# 21                  2,829  None     2,883   89.73%                    2  None
# 22                     73  None        73  100.00%                 None  None
# 23                    145  None       248   96.50%                 None  None
# 24                    111  None       111   97.37%                 None  None
# 25                  3,930  None     5,570   89.35%                  182  None
# 26                  4,333  None     6,922   91.59%                  103  None
# 27                  2,362  None     3,388   89.11%                  106  None
# 28                  1,173  None     1,190   86.36%                   11  None
# 29                   None   693     1,184   88.62%                 None    63
# 30                   None   110       144   88.89%                 None     3
# 31                     29  None        30  100.00%                 None  None
# 32                    589  None       598   85.80%                    1  None
# 33                    512  None       518   85.90%                 None  None
#
#                     col13 col14            col15   col16   col17
# 0                    None  None             None    None   TOTAL
# 1   Personas Sentenciadas  None         Subtotal       %    None
# 2                       H     M             None    None    None
# 3                    None  None  0\n:unselected:   0.00%       0
# 4                    None  None  0\n:unselected:   0.00%     307
# 5                    None  None                0   0.00%     134
# 6                    None     4                5   8.33%      60
# 7                    None  None                0   0.00%     130
# 8                    None  None                0   0.00%      77
# 9                       1  None                1   1.28%      78
# 10                    643    70            1,253  14.23%   8,805
# 11                   None    21               31  16.58%     187
# 12                    295  None              408  15.96%   2,557
# 13                     45  None               49   7.46%     657
# 14                    274  None              631  15.41%   4,096
# 15                     17  None               17   5.96%     285
# 16                      1  None                1   0.70%     143
# 17                     10  None               12   2.98%     403
# 18                   None    49              103  34.80%     296
# 19                      1  None                1   0.55%     181
# 20                  2,023   104            2,598  10.21%  25,457
# 21                    328  None              330  10.27%   3,213
# 22                   None  None                0   0.00%      73
# 23                      9  None                9   3.50%     257
# 24                      3  None                3   2.63%     114
# 25                    482  None              664  10.65%   6,234
# 26                    533  None              636   8.41%   7,558
# 27                    308  None              414  10.89%   3,802
# 28                    177  None              188  13.64%   1,378
# 29                   None    89              152  11.38%   1,336
# 30                   None    15               18  11.11%     162
# 31                   None  None                0   0.00%      30
# 32                     98  None               99  14.20%     697
# 33                     85  None               85  14.10%     603

# %%
df_final = pd.DataFrame()
for idx, table in enumerate(result1.tables):
    rows = table['rowCount']
    cols = table['columnCount']
    grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

    for cell in table['cells']:
        r = cell['rowIndex']
        c = cell['columnIndex']
        val = cell.get('content', '').strip()
        if val:
            grid[r][c] = val

    df = pd.DataFrame(grid)
    df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
    new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
    df.rename(columns=new_column_names, inplace=True)

    
    for col in range(1, df.shape[1]):
        if pd.isna(df.iat[0, col]):
            df.iat[0, col] = df.iat[0, col - 1]
    
    

    # Filter: keep only rows that match any keyword
    # Identify columns to keep
    last_column_name = df.columns[-1]
    columns_to_keep = [col for col in df.columns if column_contains_keyword(df[col])]
    actual = list(set(['col1'] + columns_to_keep + [last_column_name]))
    print(actual)
    # Filter the DataFrame
    df = df[actual]

    new_columns = []

    for i, val in enumerate(df.iloc[0]):
        if isinstance(val, str) and 'Centro' in val:
            new_columns.append('center_name')
        elif isinstance(val, str) and 'Capacidad' in val:
            new_columns.append('capacity')
        elif isinstance(val, str) and 'FEDERAL' in val:
            new_columns.append('federal')
        elif isinstance(val, str) and 'COMUN' in val:
            new_columns.append('comun')
        else:
            new_columns.append(f'total')  # fallback/default name

    # Set the new column names and drop the first row
    df.columns = new_columns
    df = df.loc[:, ~df.columns.duplicated()]
    df = df[1:].reset_index(drop=True)

    df_final = pd.concat([df_final, df])
    df_final = df_final[~df_final['center_name'].isnull()]
    df_final['month'] = 1
    df_final['year'] = 2001

df_final.to_excel(f'../../../data/00-map/capacity/raw/2001/capacity_1.xlsx', index = False)
# Out:
# ['col15', 'col17', 'col2', 'col1', 'col9']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col17', 'col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col4', 'col1', 'col2']
# ['col1', 'col5']
# ['col8', 'col1', 'col5']
# ['col4', 'col1', 'col2']
# ['col1', 'col5']
# ['col8', 'col1', 'col5']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']
# ['col2', 'col16', 'col1', 'col9', 'col14']

# %%
year = 2000
for i in range(2, 13):
    ii = f"{i:02d}"
    formUrl = f"https://raw.githubusercontent.com/ezagoc/prisions_capacity/main/raw/{year}/{year}_{ii}_CE.pdf"
    print(formUrl)
    poller = document_intelligence_client.begin_analyze_document(
        "prebuilt-layout", AnalyzeDocumentRequest(url_source=formUrl))
    result = poller.result()
    for idx, table in enumerate(result.tables):
        rows = table['rowCount']
        cols = table['columnCount']
        grid = [[np.nan for _ in range(cols)] for _ in range(rows)]

        for cell in table['cells']:
            r = cell['rowIndex']
            c = cell['columnIndex']
            val = cell.get('content', '').strip()
            if val:
                grid[r][c] = val

        df = pd.DataFrame(grid)
        df = df[~df.apply(lambda row: row.isna().all(), axis=1)]
        new_column_names = {old_name: f"col{i+1}" for i, old_name in enumerate(df.columns)}
        df.rename(columns=new_column_names, inplace=True)

        folder = Path(f"../../../data/00-map/capacity/raw/2000/tables{ii}")
        folder.mkdir(parents=True, exist_ok=True)

        df.to_parquet(f"../../../data/00-map/capacity/raw/2000/tables{ii}/table_{idx}.parquet.gzip", 
                      index = False, compression = 'gzip')
